# %%
"""
0710.学习内容:
1.Python的下载与安装&path环境变量配置
2.第一个输出Python输出语句
3.PyCharm开发工具下载安装使用
4.项目结构目录
5.字面量与变量
6.常见数据类型
7.输入与输出
8.运算符
"""

# %%
print("Hello, World!")
print("-------------")
print("Hello, Python")

print("########################")
print("#   白日依山尽          #")
print("#   黄河入海流          #")
print("########################")
# Out:
# Hello, World!
# -------------
# Hello, Python
# ########################
# #   白日依山尽          #
# #   黄河入海流          #
# ########################

# %%
print(100)
print(3.14)
print(True)
print(False)
print("Hello")
print(None)

print(100 + True)
# Out:
# 100
# 3.14
# True
# False
# Hello
# None
# 101
