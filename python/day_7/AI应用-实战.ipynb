# %%
"""
0716.学习内容:
https://github.com/Miaowzhz/learn_log
AI应用实战
    界面基本布局
    界面消息展示
    会话记忆问题
    流式输出
    侧边栏制作
    会话管理-思路分析
    会话管理-文件操作入门
    会话管理-文件操作(资源释放)
    会话管理-文件操作(json)
    会话管理-保存会话
    会话管理-新建会话
    会话管理-展示会话列表
    会话管理-加载会话
    会话管理-删除会话
    功能优化与小结
    知识扩展
"""
