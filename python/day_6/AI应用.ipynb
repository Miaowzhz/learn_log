# %%
"""
0715.学习内容:
https://github.com/Miaowzhz/learn_log
大模型部署
    方案
    Ollama本地部署
    DeepSeek官网开放API
大模型调用
    网络基础知识
    HTTP协议介绍
    HTTP请求数据格式
    ApiFox接口测试
    会话记忆方案
    本地DeepSeek
    代码调用大模型
提示词工程
    streamlit入门
    streamlit基础用法
    streamlit页面设置
实战
    准备工作(AI插件安装)
"""
